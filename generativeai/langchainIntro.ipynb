# %% [markdown]
# ### Lang Chain Version V1

# %% [markdown]
# #### API KEYs

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.9

# %%
# Load API KEYs

import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GORQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %% [markdown]
# #### Generative AI Applications using Groq api Model

# %%
from langchain.chat_models import init_chat_model

llm = init_chat_model("llama-3.1-8b-instant", model_provider="groq")
llm
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x7602af7a7320>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x7602af7a7920>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
# First Generative model
# Use the model
response = llm.invoke("Explain how to use the Groq API with LangChain in a few sentences.")
response
# Out:
# AIMessage(content="To use the Groq API with LangChain, you'll need to install both libraries and set up authentication with your Groq API key. Then, you can use LangChain's `Agent` class to create a model instance that interacts with the Groq API, allowing you to perform tasks such as question-answering and text generation. The Groq API model can be specified using LangChain's `ModelSpec` class, and the `agent.run()` method can be used to execute queries on the model.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 105, 'prompt_tokens': 52, 'total_tokens': 157, 'completion_time': 0.21069743, 'completion_tokens_details': None, 'prompt_time': 0.004137614, 'prompt_tokens_details': None, 'queue_time': 0.050501563, 'total_time': 0.214835044}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_ff2b098aaf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c465e-bf58-7832-80d1-381b24
# ...

# %%
response.content
# Out:
# "To use the Groq API with LangChain, you'll need to install both libraries and set up authentication with your Groq API key. Then, you can use LangChain's `Agent` class to create a model instance that interacts with the Groq API, allowing you to perform tasks such as question-answering and text generation. The Groq API model can be specified using LangChain's `ModelSpec` class, and the `agent.run()` method can be used to execute queries on the model."

# %% [markdown]
# #### LLM Model using Google Gemini API

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("google_genai:gemini-2.5-flash-lite")
response = model.invoke("How are you?")
response.content
# Out:
# "I am doing well, thank you for asking! As a large language model, I don't experience feelings in the same way humans do. However, I am functioning optimally and ready to assist you.\n\nHow are **you** doing today? Is there anything I can help you with?"

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
responsess = model.invoke("How are you?")
print(responsess.content)
# Out:
# I am a large language model, trained by Google.
