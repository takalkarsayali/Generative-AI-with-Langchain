# %% [markdown]
# ### Tools and Agents

# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
model=init_chat_model("groq:llama-3.1-8b-instant")

response=model.invoke("Write me an essay on AI")
response
# Out:
# AIMessage(content='**The Revolutionary Era of Artificial Intelligence**\n\nArtificial Intelligence (AI) has been a topic of interest for decades, with its roots dating back to the 1950s. However, in recent years, AI has experienced an unprecedented surge in growth and development, transforming the way we live, work, and interact with one another. This essay will explore the concept of AI, its current applications, and the potential benefits and risks associated with this rapidly evolving technology.\n\n**What is Artificial Intelligence?**\n\nAI refers to the development of computer systems that can perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making. These systems use complex algorithms and data analysis to process information and adapt to new situations. AI systems can be categorized into two main types: **narrow AI** (also known as weak AI) and **general AI** (AGI). Narrow AI is designed to perform a specific task, such as image recognition or language translation, whereas AGI is a hypothetical AI system that possesses the ability to understand, learn, and apply knowledge across a wide range of tasks, similar to human intelligence.\n\n**Current Applications of AI**\n\nAI is being applied in various industries, including healthcare, finance, transportation, and education. In healthcare, AI-powered systems are being used to analyze medical images, diagnose diseases, and develop personalized treatment plans. In finance, AI-powered chatbots are being used to assist customers with transactions and provide investment advice. In transportation, AI-powered self-driving cars are being tested on public roads, with the potential to revolutionize the way we travel. In education, AI-powered adaptive learning systems are being used to personalize learning experiences for students.\n\n**Benefits of AI**\n\nThe benefits of AI are numerous, including increased efficiency, accuracy, and productivity. AI-powered systems can process vast amounts of data quickly and accurately, reducing the risk of human error. AI can also automate repetitive tasks, freeing up human resources for more strategic and creative work. Additionally, AI can help improve decision-making by providing data-driven insights and recommendations.\n\n**Risks and Concerns of AI**\n\nWhile AI offers many benefits, there are also risks and concerns associated with its development and deployment. One of the main concerns is job displacement, as AI-powered systems replace human workers in various industries. Another concern is bias and discrimination, as AI systems may perpetuate existing social biases and stereotypes. Additionally, there are concerns about the potential for AI to be used for malicious purposes, such as cyber attacks and surveillance.\n\n**Ethical Considerations**\n\nAs AI continues to evolve and become more integrated into our lives, it is essential to consider the ethical implications of its development and deployment. This includes ensuring that AI systems are transparent, accountable, and fair. It also includes ensuring that AI is developed and deployed in a way that respects human values and promotes social welfare.\n\n**Conclusion**\n\nArtificial Intelligence is a rapidly evolving technology that has the potential to revolutionize the way we live, work, and interact with one another. While AI offers many benefits, including increased efficiency, accuracy, and productivity, there are also risks and concerns associated with its development and deployment. As AI continues to grow and become more integrated into our lives, it is essential to consider the ethical implications of its development and deployment. By doing so, we can ensure that AI is developed and deployed in a way that promotes social welfare and respects human values.\n\n**References**\n\n1. Russell, S. J., & Norvig, P. (2010). Artificial Intelligence: A Modern Approach (3rd ed.). Prentice Hall.\n2. Chouldechova, A., & Roth, A. (2018). Fai ...

# %%
## Tools
# decorator -> @tool
from langchain.tools import tool

@tool
# get weather tool creation
def get_weather(location:str)->str:
    """Get the Weather at a location"""
    return f"It's sunny in {location}"

# integrate llm model with tools
model_with_tools=model.bind_tools([get_weather])

# %%
response = model_with_tools.invoke("Whats the weather in Mumbai")
print(response)
# Out:
# content='' additional_kwargs={'tool_calls': [{'id': '1gbja4n3h', 'function': {'arguments': '{"location":"Mumbai"}', 'name': 'get_weather'}, 'type': 'function'}]} response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 217, 'total_tokens': 232, 'completion_time': 0.045727772, 'completion_tokens_details': None, 'prompt_time': 0.019247712, 'prompt_tokens_details': None, 'queue_time': 0.04901342, 'total_time': 0.064975484}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019c4b5f-9e2f-7632-893c-761175f55db2-0' tool_calls=[{'name': 'get_weather', 'args': {'location': 'Mumbai'}, 'id': '1gbja4n3h', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 217, 'output_tokens': 15, 'total_tokens': 232}

# %%
response.tool_calls
# Out:
# [{'name': 'get_weather',
#   'args': {'location': 'Mumbai'},
#   'id': '1gbja4n3h',
#   'type': 'tool_call'}]
